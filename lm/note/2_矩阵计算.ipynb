# %% [markdown]
# # 微积分

# %% [markdown]
# ## 1. 标量导数
# ![image.png](attachment:f2b51fac-55c4-4b94-babb-96c70ad1a683.png)

# %% [markdown]
# ## 2. 梯度
# - y是向量，x是标量的话，求导为标量。
# - y是标量，x是向量的话，求导为标量。
# - y是向量，x是向量的话，求导为矩阵。

# %% [markdown]
# ![image.png](attachment:f660878d-2746-4a9e-8828-1922f1070d7e.png)

# %% [markdown]
# ## 3 求导
# 标量对向量求导
# - $x_1^2+2x_2^2$是一个椭圆，梯度是指向值变化最大的方向。
# 在这里，列向量变成行向量
# ![image.png](attachment:b194cf04-0eda-4af1-a99b-0c93ad84e5e8.png)
#
# 向量对标量求导
# ![image.png](attachment:56555718-8309-40b9-a270-6461c44d96d8.png)
#
# 向量对向量求导。
# ![image.png](attachment:45be3c87-a5c8-47f9-a02d-842bf95c038d.png)
